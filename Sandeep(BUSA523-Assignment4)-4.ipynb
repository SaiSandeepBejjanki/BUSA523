# %%
conda install pandas
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas
pandas.__version__
# Out:
# '1.3.4'

# %%
conda install matplotlib
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.4.3'

# %%
import pandas as pd
import matplotlib.pyplot as plt

asgndata=pd.read_csv("data.csv")
asgndata
# Out:
#            Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0        5/2/10        42.31       2.572        NaN        NaN        NaN
# 1       12/2/10        38.51       2.548        NaN        NaN        NaN
# 2    19/02/2010        39.93       2.514        NaN        NaN        NaN
# 3    26/02/2010        46.63       2.561        NaN        NaN        NaN
# 4        5/3/10        46.50       2.625        NaN        NaN        NaN
# ..          ...          ...         ...        ...        ...        ...
# 138  28/09/2012        76.08       3.666    3666.27       7.64       1.65
# 139     5/10/12        68.55       3.617    8077.89        NaN      18.22
# 140    12/10/12        62.99       3.601    2086.18        NaN       8.11
# 141  19/10/2012        67.97       3.594     950.33        NaN       4.93
# 142  26/10/2012        69.16       3.506    2585.85      31.75       6.00
#
#      MarkDown4  MarkDown5         CPI  Unemployment     Day type  \
# ...

# %% [markdown]
# # Histogram

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('default')
# %matplotlib notebook

histogram = asgndata.CPI.plot.hist(bins=15, color="purple", ec="red", grid=False, figsize=(8,6), legend=True)
histogram.set_title("Histogram - CPI Distribution", color="black", fontsize=18)
histogram.set_xlabel("CPI Values", color="red", fontsize=12)
plt.show()

histogram.figure.savefig("Histogram.png")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Histogram with multiple variables (Same Frame)

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('bmh')
# %matplotlib notebook

histgm=asgndata[['MarkDown1', 'MarkDown2', 'MarkDown3']].plot.hist(color=['green', 'orange', 'blue'], ec="white", grid=True, legend=True, alpha=0.4)
histgm.set_title("Histogram with multiple variables in same chart", color="black", fontsize=18)
histgm.set_xlabel("CPI Values", color="red", fontsize=12)
plt.show()

histgm.figure.savefig("HistogramWithMV1.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Histogram With Multiple Variables (Each Individual Frame)

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib notebook

hstgrm1=asgndata[['dept_1 sales', 'dept_2 sales', 'dept_3 sales']].hist(bins=15, color="#ADD8E6", ec="black", figsize=(13,6), legend=True, alpha=0.6)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1040">

# %% [markdown]
# # BarChart

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('default')
# %matplotlib notebook

barchart=asgndata.plot.bar(x='Day type', y='Fuel_Price', color="olive", legend=True, figsize=(24,6))
plt.show()

barchart.figure.savefig("Barchart.png")
# Out:
# <img src="data:image/png;base64,..." width="2400">

# %% [markdown]
# # LineChart

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
# %matplotlib notebook

linechart=asgndata.plot.line(x='Date', y='dept_1 sales', color="magenta", legend=True, figsize=(24,6))
plt.show()
linechart.figure.savefig("Linechart.png")
# Out:
# <img src="data:image/png;base64,..." width="1920">

# %% [markdown]
# # AreaChart

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
# %matplotlib notebook

areachart=asgndata.plot.area(x='Date', y='Temperature', color="salmon", legend=True)
plt.show()

areachart.figure.savefig("Areachart.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # ScatterPlot

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib notebook

plt.axvline(65, c=(.5, .5, .5), ls='--')
plt.axhline(3.2, c=(.5, .5, .5), ls='--')
scatterplot= plt.scatter(asgndata.Temperature, asgndata.Fuel_Price, c=asgndata.Fuel_Price, cmap='Spectral', ec='k', s=30)
plt.colorbar(label='Fuel_Price')

plt.show()

scatterplot.figure.savefig("Scatterplot.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
